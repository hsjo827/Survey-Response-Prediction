# %%
# Data Wrangling
import pandas as pd
import numpy as np
import gzip
import gc

# Visualization, EDA
import missingno as msno
import matplotlib.pylab as plt
from matplotlib import font_manager, rc
import seaborn as sns
# %matplotlib inline

# Korean font
#font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
#rc('font', family=font_name)

# Preprocessing & Feature Engineering
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.feature_selection import SelectPercentile

# Hyperparameter Optimization
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import optuna

# Modeling
from lightgbm import LGBMClassifier
from sklearn.dummy import DummyClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import *
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.base import ClassifierMixin

# Evaluation
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

from keras.callbacks import ModelCheckpoint

# Utility
import re
import os
import time
import datetime
import random
import tensorflow as tf
import pickle
import joblib
import platform
import warnings; warnings.filterwarnings("ignore")
from itertools import combinations
from tqdm import tqdm, tqdm_notebook
from IPython.display import Image
from scipy.stats.mstats import gmean
from tensorflow import keras
from PIL import Image
from tqdm.auto import trange

from sklearn.datasets import make_classification

from sklearn.ensemble import BaggingClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.model_selection import KFold

import shap # v2.0부터 추가
from featurizer import KMeansFeaturizer # v2.0부터 추가
import gzip
import pickle

# %%
with gzip.open('last dance_3.zip','rb') as f:
   train,test,X_train, y_train, X_test, ID_test, cat_features, num_features = pickle.load(f)

# %% [markdown]
# ## Model building

# %% [markdown]
# # DNN

# %%
# seed 값을 재설정하는 함수
def reset_seeds(SEED, reset_graph_with_backend=None):
    if reset_graph_with_backend is not None:
        K = reset_graph_with_backend
        K.clear_session()
        tf.compat.v1.reset_default_graph()
        print("KERAS AND TENSORFLOW GRAPHS RESET")  # optional

    np.random.seed(SEED)
    random.seed(SEED)
    tf.compat.v1.set_random_seed(SEED)
#    os.environ['CUDA_VISIBLE_DEVICES'] = ''  # for GPU
    print("RANDOM SEEDS RESET: ", SEED)  # optional

# %%
# 예측값을 저장할 폴더 생성
folder = 'last dance'
if not os.path.isdir(folder):
    os.mkdir(folder)

# %%
# 사용할 seed 값 목록
seed_values = [96, 513, 661, 933, 1030, 1549, 2525, 3521, 3674, 4484, 4686, 4944, 6678, 6781, 8888, 8947, 9570, 9624, 9639, 9715]

# 각 seed 값에 대해 모델 학습 및 예측 수행
for SEED in seed_values:
    reset_seeds(SEED)
    
    # 신경망 아케텍처 정의
    input = keras.Input(shape=(X_train.shape[1],))
    x = keras.layers.Dense(32, activation='relu')(input)
    x = keras.layers.Dense(16, activation='relu')(x)
    output = keras.layers.Dense(1, activation='sigmoid')(x)
    model = keras.Model(input, output)    

    # Optimizer와 Loss Function 정의
    model.compile(loss='binary_crossentropy', optimizer=keras.optimizers.Nadam(learning_rate=0.001), metrics=['accuracy'])
    
    # 모델 학습
    callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)]
    hist = model.fit(X_train, y_train, validation_split=0.2, batch_size=4096, epochs=50, 
                     callbacks=callbacks, shuffle=False, verbose=0)
    print("validation accuracy = ", hist.history['val_accuracy'][-1])
    
    # 예측값 저장
    submission = pd.DataFrame({
        "ID": ID_test, 
        "STATUS": (model.predict(X_test).flatten() >= 0.495).astype(int)
    })
    t = pd.Timestamp.now()
    fname = f"{folder}/loop_submission_{t.month:02}{t.day:02}_{SEED:05}.csv"
    submission.to_csv(fname, index=False)
# Out:
# RANDOM SEEDS RESET:  96
# validation accuracy =  0.9029005169868469
# 16934/16934 [==============================] - 24s 1ms/step
# RANDOM SEEDS RESET:  513
# validation accuracy =  0.9018681049346924
# 16934/16934 [==============================] - 36s 2ms/step
# RANDOM SEEDS RESET:  661

# %%
# 저장된 예측값 파일들을 종합하여 최종 예측값 생성
nf = 0
for f in os.listdir(folder):
    ext = os.path.splitext(f)[-1]
    if ext == '.csv': 
        s = pd.read_csv(folder+"/"+f)
    else: 
        continue
    if len(s.columns) !=2:
        continue
    if nf == 0: 
        slist = s
    else: 
        slist = pd.merge(slist, s, on="ID", suffixes=('',f'_{nf}'))
    nf += 1

# 여러 예측값을 평균내어 최종 예측값 생성
if nf >= 2:
    pred = 0
    for j in range(nf): pred = pred + slist.iloc[:,j+1]
    pred = pred / nf   
    pred = pred.apply(lambda x: 1 if x >= 0.5 else 0)    
    submission = pd.DataFrame({'ID': slist.ID, 'STATUS': pred})
    t = pd.Timestamp.now()
    fname = f"dnn_submission_{t.month:02}{t.day:02}_{t.hour:02}{t.minute:02}.csv"
    submission.to_csv(fname, index=False)

# %% [markdown]
# # LGBM OOF

# %%
# LightGBM 모델 설정 및 K-Fold 교차 검증 수행
kf = KFold(n_splits=5, shuffle=True, random_state=0)
model = LGBMClassifier(random_state=0, n_estimators=1000)

lgbm_pred = np.zeros((X_test.shape[0]))
accuracy_list = []
threshold=0.495 # 이진 분류 임계값 설정

# 5-Fold 교차 검증 루프
for tr_idx, val_idx in tqdm(kf.split(X_train, y_train)):
    tr_x, tr_y = X_train.iloc[tr_idx], y_train.iloc[tr_idx] # 학습 데이터 분할
    val_x, val_y = X_train.iloc[val_idx], y_train.iloc[val_idx] # 검증 데이터 분할
    
    model.fit(tr_x, tr_y) # 모델 학습
    pred_probs = model.predict_proba(val_x)[:, 1]  # 검증 데이터에 대한 예측 확률값
    
    
    # 예측 클래스를 임계값(threshold)에 따라 이진화
    pred = (pred_probs >= threshold).astype(int)
    
    accuracy = accuracy_score(val_y, pred) # 정확도 계산
    accuracy_list.append(accuracy)
    print(f'Fold Accuracy: {accuracy:.4f}')
    
    sub_pred = model.predict_proba(X_test)[:, 1] / 5  # 테스트 데이터에 대한 예측 확률값 누적
    lgbm_pred += sub_pred

# 테스트 데이터에 대한 최종 예측 클래스를 임계값(threshold)에 따라 이진화
lgbm_pred_binary = (lgbm_pred >= threshold).astype(int)

print(f'{model.__class__.__name__}의 5-fold 평균 Accuracy는 {np.mean(accuracy_list)}')
# Out:
# 0it [00:00, ?it/s]
# [LightGBM] [Info] Number of positive: 253313, number of negative: 397607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.039815 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2269
# [LightGBM] [Info] Number of data points in the train set: 650920, number of used features: 46
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.389161 -> initscore=-0.450838
# [LightGBM] [Info] Start training from score -0.450838
# Fold Accuracy: 0.8669
# 1it [00:24, 24.54s/it]
# [LightGBM] [Info] Number of positive: 253014, number of negative: 397906
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.037133 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2278
# [LightGBM] [Info] Number of data points in the train set: 650920, number of used features: 46
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.388702 -> initscore=-0.452771
# [LightGBM] [Info] Start training from score -0.452771
# Fold Accuracy: 0.8678
# 2it [00:52, 26.62s/it]
# [LightGBM] [Info] Number of positive: 253311, number of negative: 397609
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.037660 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2279
# [LightGBM] [Info] Number of data points in the train set: 650920, number of used features: 46
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.389158 -> initscore=-0.450851
# [LightGBM] [Info] Start training from score -0.450851
# Fold Accuracy: 0.8688
# 3it [01:20, 27.31s/it]
# [LightGBM] [Info] Number of positive: 253289, number of negative: 397631
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.036558 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2270
# [LightGBM] [Info] Number of data points in the train set: 650920, number of used features: 46
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.389125 -> initscore=-0.450993
# [LightGBM] [Info] Start training from score -0.450993
# Fold Accuracy: 0.8672
# 4it [01:49, 27.74s/it]
# [LightGBM] [Info] Number of positive: 253333, number of negative: 397587
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.036813 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2269
# [LightGBM] [Info] Number of data points in the train set: 650920, number of used features: 46
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.389192 -> initscore=-0.450709
# [LightGBM] [Info] Start training from score -0.450709
# Fold Accuracy: 0.8681
# 5it [02:17, 27.54s/it]
# LGBMClassifier의 5-fold 평균 Accuracy는 0.867762551465618

# %%
# LightGBM 모델의 예측 결과 저장
t = pd.Timestamp.now()
fname = f"lgbm_submission_{t.month:02}{t.day:02}{t.hour:02}{t.minute:02}.csv"
pd.DataFrame({'ID': ID_test, 'STATUS': lgbm_pred_binary}).to_csv(fname, index=False)
print(f"'{fname}' is ready to submit.")

# %% [markdown]
# # CAT OOF

# %%
# CatBoost 모델 설정 및 K-Fold 교차 검증 수행
kf = KFold(n_splits=5, shuffle=True, random_state=0)
model = CatBoostClassifier(random_state=0, n_estimators=1000)

cat_pred = np.zeros((X_test.shape[0]))
accuracy_list = []
threshold=0.495 # 이진 분류 임계값 설정

# 5-Fold 교차 검증 루프
for tr_idx, val_idx in tqdm(kf.split(X_train, y_train)):
    tr_x, tr_y = X_train.iloc[tr_idx], y_train.iloc[tr_idx]
    val_x, val_y = X_train.iloc[val_idx], y_train.iloc[val_idx]
    
    model.fit(tr_x, tr_y) # 모델 학습
    pred_probs = model.predict_proba(val_x)[:, 1] # 검증 데이터에 대한 예측 확률값
    
    
    # 예측 클래스를 임계값(threshold)에 따라 이진화
    pred = (pred_probs >= threshold).astype(int)
    
    accuracy = accuracy_score(val_y, pred) # 정확도 계산
    accuracy_list.append(accuracy)
    print(f'Fold Accuracy: {accuracy}')
    
    sub_pred = model.predict_proba(X_test)[:, 1] / 5  # 테스트 데이터에 대한 예측 확률값 누적
    cat_pred += sub_pred

# 테스트 데이터에 대한 최종 예측 클래스를 임계값(threshold)에 따라 이진화
cat_pred_binary = (cat_pred >= threshold).astype(int)

print(f'{model.__class__.__name__}의 5-fold 평균 Accuracy는 {np.mean(accuracy_list)}')
# Out:
# 0it [00:00, ?it/s]
# Learning rate set to 0.163799
# 0:	learn: 0.4981496	total: 319ms	remaining: 5m 18s
# 1:	learn: 0.4443432	total: 387ms	remaining: 3m 13s
# 2:	learn: 0.4018206	total: 464ms	remaining: 2m 34s
# 3:	learn: 0.3802343	total: 549ms	remaining: 2m 16s
# 4:	learn: 0.3647510	total: 627ms	remaining: 2m 4s
# 5:	learn: 0.3535435	total: 712ms	remaining: 1m 58s
# 6:	learn: 0.3456894	total: 790ms	remaining: 1m 52s
# 7:	learn: 0.3396548	total: 858ms	remaining: 1m 46s
# 8:	learn: 0.3351058	total: 922ms	remaining: 1m 41s
# 9:	learn: 0.3316733	total: 979ms	remaining: 1m 36s
# 10:	learn: 0.3290235	total: 1.04s	remaining: 1m 33s
# 11:	learn: 0.3268102	total: 1.11s	remaining: 1m 31s
# 102:	learn: 0.2924021	total: 8.4s	remaining: 1m 13s
# 103:	learn: 0.2923022	total: 8.48s	remaining: 1m 13s
# 104:	learn: 0.2922327	total: 8.55s	remaining: 1m 12s
# 105:	learn: 0.2921256	total: 8.63s	remaining: 1m 12s
# 106:	learn: 0.2920456	total: 8.72s	remaining: 1m 12s
# 107:	learn: 0.2919961	total: 8.8s	remaining: 1m 12s
# 108:	learn: 0.2919350	total: 8.87s	remaining: 1m 12s
# 109:	learn: 0.2918177	total: 8.96s	remaining: 1m 12s
# 110:	learn: 0.2917439	total: 9.04s	remaining: 1m 12s
# 111:	learn: 0.2916889	total: 9.13s	remaining: 1m 12s
# 112:	learn: 0.2916344	total: 9.2s	remaining: 1m 12s
# 113:	learn: 0.2915296	total: 9.28s	remaining: 1m 12s
# 114:	learn: 0.2914604	total: 9.35s	remaining: 1m 11s
# 115:	learn: 0.2913926	total: 9.43s	remaining: 1m 11s
# 116:	learn: 0.2912455	total: 9.52s	remaining: 1m 11s
# 117:	learn: 0.2911740	total: 9.61s	remaining: 1m 11s
# 118:	learn: 0.2910957	total: 9.72s	remaining: 1m 11s
# 119:	learn: 0.2910256	total: 9.81s	remaining: 1m 11s
# 120:	learn: 0.2909687	total: 9.93s	remaining: 1m 12s
# 121:	learn: 0.2908970	total: 10s	remaining: 1m 12s
# 122:	learn: 0.2908466	total: 10.1s	remaining: 1m 12s
# 123:	learn: 0.2907642	total: 10.2s	remaining: 1m 12s
# 124:	learn: 0.2907020	total: 10.3s	remaining: 1m 12s
# 125:	learn: 0.2906377	total: 10.4s	remaining: 1m 12s
# 126:	learn: 0.2905081	total: 10.5s	remaining: 1m 12s
# 127:	learn: 0.2904529	total: 10.6s	remaining: 1m 12s
# 128:	learn: 0.2904104	total: 10.7s	remaining: 1m 12s
# 129:	learn: 0.2903858	total: 10.8s	remaining: 1m 12s
# 130:	learn: 0.2903358	total: 10.9s	remaining: 1m 12s
# 131:	learn: 0.2902838	total: 11s	remaining: 1m 12s
# 132:	learn: 0.2902506	total: 11s	remaining: 1m 11s
# 133:	learn: 0.2902094	total: 11.1s	remaining: 1m 11s
# 134:	learn: 0.2901415	total: 11.2s	remaining: 1m 11s
# 135:	learn: 0.2900722	total: 11.3s	remaining: 1m 11s
# 136:	learn: 0.2899979	total: 11.4s	remaining: 1m 11s
# 137:	learn: 0.2899385	total: 11.5s	remaining: 1m 11s
# 138:	learn: 0.2898989	total: 11.5s	remaining: 1m 11s
# 139:	learn: 0.2898291	total: 11.6s	remaining: 1m 11s
# 140:	learn: 0.2897629	total: 11.7s	remaining: 1m 11s
# 141:	learn: 0.2896862	total: 11.8s	remaining: 1m 11s
# 142:	learn: 0.2896246	total: 11.8s	remaining: 1m 11s
# 143:	learn: 0.2895677	total: 11.9s	remaining: 1m 10s
# 144:	learn: 0.2894839	total: 12s	remaining: 1m 10s
# 145:	learn: 0.2894095	total: 12.1s	remaining: 1m 10s
# 146:	learn: 0.2893835	total: 12.2s	remaining: 1m 10s
# 147:	learn: 0.2892944	total: 12.2s	remaining: 1m 10s
# 148:	learn: 0.2892344	total: 12.3s	remaining: 1m 10s
# 149:	learn: 0.2892093	total: 12.4s	remaining: 1m 10s
# 150:	learn: 0.2891415	total: 12.5s	remaining: 1m 10s
# 151:	learn: 0.2890973	total: 12.6s	remaining: 1m 10s
# 152:	learn: 0.2890273	total: 12.6s	remaining: 1m 9s
# 153:	learn: 0.2890145	total: 12.7s	remaining: 1m 9s
# 154:	learn: 0.2889613	total: 12.8s	remaining: 1m 9s
# 155:	learn: 0.2889152	total: 12.9s	remaining: 1m 9s
# 156:	learn: 0.2888467	total: 12.9s	remaining: 1m 9s
# 157:	learn: 0.2887968	total: 13s	remaining: 1m 9s
# 158:	learn: 0.2887306	total: 13.1s	remaining: 1m 9s
# 159:	learn: 0.2886960	total: 13.2s	remaining: 1m 9s
# 160:	learn: 0.2886632	total: 13.2s	remaining: 1m 9s
# 161:	learn: 0.2886002	total: 13.3s	remaining: 1m 8s
# 162:	learn: 0.2885301	total: 13.4s	remaining: 1m 8s
# 163:	learn: 0.2884946	total: 13.5s	remaining: 1m 8s
# 164:	learn: 0.2884467	total: 13.5s	remaining: 1m 8s
# 165:	learn: 0.2884102	total: 13.6s	remaining: 1m 8s
# 166:	learn: 0.2883813	total: 13.7s	remaining: 1m 8s
# 167:	learn: 0.2883274	total: 13.8s	remaining: 1m 8s
# 168:	learn: 0.2882753	total: 13.9s	remaining: 1m 8s
# 169:	learn: 0.2882422	total: 13.9s	remaining: 1m 8s
# 170:	learn: 0.2881869	total: 14s	remaining: 1m 7s
# 171:	learn: 0.2881471	total: 14.1s	remaining: 1m 7s
# 172:	learn: 0.2881314	total: 14.2s	remaining: 1m 7s
# 173:	learn: 0.2880967	total: 14.2s	remaining: 1m 7s
# 174:	learn: 0.2880479	total: 14.3s	remaining: 1m 7s
# 175:	learn: 0.2879943	total: 14.4s	remaining: 1m 7s
# 176:	learn: 0.2879571	total: 14.5s	remaining: 1m 7s
# 177:	learn: 0.2879017	total: 14.5s	remaining: 1m 7s
# 178:	learn: 0.2878705	total: 14.6s	remaining: 1m 7s
# 179:	learn: 0.2878215	total: 14.7s	remaining: 1m 6s
# 180:	learn: 0.2877676	total: 14.8s	remaining: 1m 6s
# 181:	learn: 0.2877241	total: 14.9s	remaining: 1m 6s
# 182:	learn: 0.2876506	total: 14.9s	remaining: 1m 6s
# 183:	learn: 0.2876285	total: 15s	remaining: 1m 6s
# 184:	learn: 0.2875608	total: 15.1s	remaining: 1m 6s
# 185:	learn: 0.2875027	total: 15.2s	remaining: 1m 6s
# 186:	learn: 0.2874795	total: 15.3s	remaining: 1m 6s
# 187:	learn: 0.2874058	total: 15.4s	remaining: 1m 6s
# 188:	learn: 0.2873285	total: 15.4s	remaining: 1m 6s
# 189:	learn: 0.2872676	total: 15.5s	remaining: 1m 6s
# 190:	learn: 0.2872361	total: 15.6s	remaining: 1m 6s
# 191:	learn: 0.2871819	total: 15.7s	remaining: 1m 5s
# 754:	learn: 0.2736935	total: 1m 1s	remaining: 19.8s
# 755:	learn: 0.2736719	total: 1m 1s	remaining: 19.8s
# 756:	learn: 0.2736548	total: 1m 1s	remaining: 19.7s
# 757:	learn: 0.2736436	total: 1m 1s	remaining: 19.6s
# 758:	learn: 0.2736285	total: 1m 1s	remaining: 19.5s
# 759:	learn: 0.2736140	total: 1m 1s	remaining: 19.5s
# 760:	learn: 0.2736059	total: 1m 1s	remaining: 19.4s
# 761:	learn: 0.2735837	total: 1m 1s	remaining: 19.3s
# 762:	learn: 0.2735753	total: 1m 2s	remaining: 19.3s
# 763:	learn: 0.2735604	total: 1m 2s	remaining: 19.2s
# 764:	learn: 0.2735387	total: 1m 2s	remaining: 19.1s
# 765:	learn: 0.2735228	total: 1m 2s	remaining: 19s
# 766:	learn: 0.2735064	total: 1m 2s	remaining: 19s
# 767:	learn: 0.2734835	total: 1m 2s	remaining: 18.9s
# 768:	learn: 0.2734659	total: 1m 2s	remaining: 18.8s
# 769:	learn: 0.2734564	total: 1m 2s	remaining: 18.7s
# 770:	learn: 0.2734415	total: 1m 2s	remaining: 18.7s
# 771:	learn: 0.2734293	total: 1m 2s	remaining: 18.6s
# 772:	learn: 0.2734119	total: 1m 3s	remaining: 18.5s
# 773:	learn: 0.2733925	total: 1m 3s	remaining: 18.4s
# 774:	learn: 0.2733771	total: 1m 3s	remaining: 18.4s
# 775:	learn: 0.2733586	total: 1m 3s	remaining: 18.3s
# 776:	learn: 0.2733374	total: 1m 3s	remaining: 18.2s
# 777:	learn: 0.2733119	total: 1m 3s	remaining: 18.2s
# 778:	learn: 0.2733023	total: 1m 3s	remaining: 18.1s
# 779:	learn: 0.2732799	total: 1m 3s	remaining: 18s
# 780:	learn: 0.2732611	total: 1m 3s	remaining: 17.9s
# 781:	learn: 0.2732465	total: 1m 4s	remaining: 17.9s
# 782:	learn: 0.2732236	total: 1m 4s	remaining: 17.8s
# 783:	learn: 0.2732123	total: 1m 4s	remaining: 17.7s
# 784:	learn: 0.2731966	total: 1m 4s	remaining: 17.6s
# 785:	learn: 0.2731827	total: 1m 4s	remaining: 17.6s
# 786:	learn: 0.2731761	total: 1m 4s	remaining: 17.5s
# 787:	learn: 0.2731605	total: 1m 4s	remaining: 17.4s
# 788:	learn: 0.2731424	total: 1m 4s	remaining: 17.3s
# 789:	learn: 0.2731180	total: 1m 4s	remaining: 17.3s
# 790:	learn: 0.2731038	total: 1m 5s	remaining: 17.2s
# 791:	learn: 0.2730813	total: 1m 5s	remaining: 17.1s
# 792:	learn: 0.2730620	total: 1m 5s	remaining: 17s
# 793:	learn: 0.2730479	total: 1m 5s	remaining: 17s
# 794:	learn: 0.2730286	total: 1m 5s	remaining: 16.9s
# 795:	learn: 0.2730085	total: 1m 5s	remaining: 16.8s
# 796:	learn: 0.2729944	total: 1m 5s	remaining: 16.7s
# 797:	learn: 0.2729789	total: 1m 5s	remaining: 16.6s
# 798:	learn: 0.2729606	total: 1m 5s	remaining: 16.6s
# 799:	learn: 0.2729489	total: 1m 5s	remaining: 16.5s
# 800:	learn: 0.2729379	total: 1m 5s	remaining: 16.4s
# 801:	learn: 0.2729270	total: 1m 6s	remaining: 16.3s
# 802:	learn: 0.2729076	total: 1m 6s	remaining: 16.2s
# 803:	learn: 0.2728874	total: 1m 6s	remaining: 16.1s
# 804:	learn: 0.2728675	total: 1m 6s	remaining: 16.1s
# 805:	learn: 0.2728534	total: 1m 6s	remaining: 16s
# 806:	learn: 0.2728315	total: 1m 6s	remaining: 15.9s
# 807:	learn: 0.2728141	total: 1m 6s	remaining: 15.8s
# 808:	learn: 0.2727971	total: 1m 6s	remaining: 15.7s
# 809:	learn: 0.2727771	total: 1m 6s	remaining: 15.7s
# 810:	learn: 0.2727639	total: 1m 6s	remaining: 15.6s
# 811:	learn: 0.2727464	total: 1m 6s	remaining: 15.5s
# 812:	learn: 0.2727321	total: 1m 7s	remaining: 15.4s
# 813:	learn: 0.2727157	total: 1m 7s	remaining: 15.3s
# 814:	learn: 0.2726932	total: 1m 7s	remaining: 15.3s
# 815:	learn: 0.2726826	total: 1m 7s	remaining: 15.2s
# 816:	learn: 0.2726620	total: 1m 7s	remaining: 15.1s
# 817:	learn: 0.2726437	total: 1m 7s	remaining: 15s
# 818:	learn: 0.2726284	total: 1m 7s	remaining: 14.9s
# 819:	learn: 0.2726145	total: 1m 7s	remaining: 14.8s
# 820:	learn: 0.2725970	total: 1m 7s	remaining: 14.8s
# 821:	learn: 0.2725799	total: 1m 7s	remaining: 14.7s
# 822:	learn: 0.2725673	total: 1m 7s	remaining: 14.6s
# 823:	learn: 0.2725520	total: 1m 7s	remaining: 14.5s
# 824:	learn: 0.2725264	total: 1m 8s	remaining: 14.4s
# 825:	learn: 0.2725102	total: 1m 8s	remaining: 14.4s
# 826:	learn: 0.2724902	total: 1m 8s	remaining: 14.3s
# 827:	learn: 0.2724714	total: 1m 8s	remaining: 14.2s
# 828:	learn: 0.2724541	total: 1m 8s	remaining: 14.1s
# 829:	learn: 0.2724391	total: 1m 8s	remaining: 14s
# 830:	learn: 0.2724230	total: 1m 8s	remaining: 14s
# 831:	learn: 0.2724151	total: 1m 8s	remaining: 13.9s
# 832:	learn: 0.2724015	total: 1m 8s	remaining: 13.8s
# 833:	learn: 0.2723895	total: 1m 8s	remaining: 13.7s
# 834:	learn: 0.2723656	total: 1m 8s	remaining: 13.6s
# 835:	learn: 0.2723463	total: 1m 9s	remaining: 13.6s
# 836:	learn: 0.2723126	total: 1m 9s	remaining: 13.5s
# 837:	learn: 0.2722957	total: 1m 9s	remaining: 13.4s
# 838:	learn: 0.2722830	total: 1m 9s	remaining: 13.3s
# 839:	learn: 0.2722705	total: 1m 9s	remaining: 13.2s
# 840:	learn: 0.2722583	total: 1m 9s	remaining: 13.1s
# 841:	learn: 0.2722436	total: 1m 9s	remaining: 13.1s
# 842:	learn: 0.2722252	total: 1m 9s	remaining: 13s
# 843:	learn: 0.2722048	total: 1m 9s	remaining: 12.9s
# 844:	learn: 0.2721887	total: 1m 9s	remaining: 12.8s
# 845:	learn: 0.2721743	total: 1m 9s	remaining: 12.7s
# 846:	learn: 0.2721679	total: 1m 10s	remaining: 12.7s
# 847:	learn: 0.2721497	total: 1m 10s	remaining: 12.6s
# 848:	learn: 0.2721435	total: 1m 10s	remaining: 12.5s
# 849:	learn: 0.2721265	total: 1m 10s	remaining: 12.4s
# 850:	learn: 0.2721164	total: 1m 10s	remaining: 12.3s
# 851:	learn: 0.2721005	total: 1m 10s	remaining: 12.2s
# 852:	learn: 0.2720727	total: 1m 10s	remaining: 12.2s
# 853:	learn: 0.2720638	total: 1m 10s	remaining: 12.1s
# 854:	learn: 0.2720486	total: 1m 10s	remaining: 12s
# 855:	learn: 0.2720268	total: 1m 10s	remaining: 11.9s
# 856:	learn: 0.2720124	total: 1m 10s	remaining: 11.8s
# 857:	learn: 0.2719952	total: 1m 11s	remaining: 11.8s
# 858:	learn: 0.2719809	total: 1m 11s	remaining: 11.7s
# 859:	learn: 0.2719689	total: 1m 11s	remaining: 11.6s
# 860:	learn: 0.2719523	total: 1m 11s	remaining: 11.5s
# 861:	learn: 0.2719371	total: 1m 11s	remaining: 11.4s
# 862:	learn: 0.2719228	total: 1m 11s	remaining: 11.3s
# 863:	learn: 0.2719086	total: 1m 11s	remaining: 11.3s
# 864:	learn: 0.2718979	total: 1m 11s	remaining: 11.2s
# 865:	learn: 0.2718844	total: 1m 11s	remaining: 11.1s
# 866:	learn: 0.2718676	total: 1m 11s	remaining: 11s
# 867:	learn: 0.2718564	total: 1m 11s	remaining: 10.9s
# 868:	learn: 0.2718500	total: 1m 11s	remaining: 10.8s
# 869:	learn: 0.2718335	total: 1m 11s	remaining: 10.8s
# 870:	learn: 0.2718140	total: 1m 12s	remaining: 10.7s
# 871:	learn: 0.2717936	total: 1m 12s	remaining: 10.6s
# 872:	learn: 0.2717804	total: 1m 12s	remaining: 10.5s
# 873:	learn: 0.2716990	total: 1m 12s	remaining: 10.4s
# 874:	learn: 0.2716816	total: 1m 12s	remaining: 10.3s
# 875:	learn: 0.2716659	total: 1m 12s	remaining: 10.3s
# 876:	learn: 0.2716466	total: 1m 12s	remaining: 10.2s
# 877:	learn: 0.2716282	total: 1m 12s	remaining: 10.1s
# 878:	learn: 0.2716121	total: 1m 12s	remaining: 10s
# 879:	learn: 0.2715995	total: 1m 12s	remaining: 9.93s
# 880:	learn: 0.2715813	total: 1m 12s	remaining: 9.84s
# 881:	learn: 0.2715669	total: 1m 12s	remaining: 9.76s
# 882:	learn: 0.2715472	total: 1m 13s	remaining: 9.68s
# 883:	learn: 0.2715343	total: 1m 13s	remaining: 9.6s
# 884:	learn: 0.2715201	total: 1m 13s	remaining: 9.51s
# 885:	learn: 0.2715035	total: 1m 13s	remaining: 9.43s
# 886:	learn: 0.2714812	total: 1m 13s	remaining: 9.35s
# 887:	learn: 0.2714631	total: 1m 13s	remaining: 9.27s
# 888:	learn: 0.2714509	total: 1m 13s	remaining: 9.19s
# 889:	learn: 0.2714372	total: 1m 13s	remaining: 9.1s
# 890:	learn: 0.2714256	total: 1m 13s	remaining: 9.02s
# 891:	learn: 0.2714067	total: 1m 13s	remaining: 8.93s
# 892:	learn: 0.2713807	total: 1m 13s	remaining: 8.85s
# 893:	learn: 0.2713657	total: 1m 13s	remaining: 8.77s
# 894:	learn: 0.2713440	total: 1m 14s	remaining: 8.68s
# 895:	learn: 0.2713252	total: 1m 14s	remaining: 8.6s
# 896:	learn: 0.2713082	total: 1m 14s	remaining: 8.52s
# 897:	learn: 0.2712974	total: 1m 14s	remaining: 8.43s
# 898:	learn: 0.2712856	total: 1m 14s	remaining: 8.35s
# 899:	learn: 0.2712715	total: 1m 14s	remaining: 8.27s
# 900:	learn: 0.2712546	total: 1m 14s	remaining: 8.19s
# 901:	learn: 0.2712390	total: 1m 14s	remaining: 8.1s
# 902:	learn: 0.2712230	total: 1m 14s	remaining: 8.02s
# 903:	learn: 0.2712027	total: 1m 14s	remaining: 7.94s
# 904:	learn: 0.2711891	total: 1m 14s	remaining: 7.85s
# 905:	learn: 0.2711757	total: 1m 14s	remaining: 7.77s
# 906:	learn: 0.2711629	total: 1m 14s	remaining: 7.68s
# 907:	learn: 0.2711441	total: 1m 15s	remaining: 7.6s
# 908:	learn: 0.2711358	total: 1m 15s	remaining: 7.52s
# 909:	learn: 0.2711194	total: 1m 15s	remaining: 7.43s
# 910:	learn: 0.2711002	total: 1m 15s	remaining: 7.35s
# 911:	learn: 0.2710842	total: 1m 15s	remaining: 7.27s
# 912:	learn: 0.2710698	total: 1m 15s	remaining: 7.18s
# 913:	learn: 0.2710538	total: 1m 15s	remaining: 7.1s
# 914:	learn: 0.2710436	total: 1m 15s	remaining: 7.02s
# 915:	learn: 0.2710222	total: 1m 15s	remaining: 6.93s
# 916:	learn: 0.2710145	total: 1m 15s	remaining: 6.85s
# 917:	learn: 0.2709951	total: 1m 15s	remaining: 6.77s
# 918:	learn: 0.2709830	total: 1m 15s	remaining: 6.68s
# 919:	learn: 0.2709711	total: 1m 15s	remaining: 6.6s
# 920:	learn: 0.2709536	total: 1m 15s	remaining: 6.52s
# 921:	learn: 0.2709392	total: 1m 16s	remaining: 6.43s
# 922:	learn: 0.2709202	total: 1m 16s	remaining: 6.35s
# 923:	learn: 0.2708918	total: 1m 16s	remaining: 6.27s
# 924:	learn: 0.2708803	total: 1m 16s	remaining: 6.18s
# 925:	learn: 0.2708597	total: 1m 16s	remaining: 6.1s
# ...
# 698:	learn: 0.2748142	total: 1m 1s	remaining: 26.5s
# 699:	learn: 0.2747988	total: 1m 1s	remaining: 26.4s
# 700:	learn: 0.2747828	total: 1m 1s	remaining: 26.3s
# 701:	learn: 0.2747724	total: 1m 1s	remaining: 26.2s
# 702:	learn: 0.2747559	total: 1m 1s	remaining: 26.1s
# 703:	learn: 0.2747432	total: 1m 1s	remaining: 26s
# 704:	learn: 0.2747223	total: 1m 2s	remaining: 26s
# 705:	learn: 0.2747115	total: 1m 2s	remaining: 25.9s
# 706:	learn: 0.2746940	total: 1m 2s	remaining: 25.8s
# 707:	learn: 0.2746713	total: 1m 2s	remaining: 25.7s
# 708:	learn: 0.2746526	total: 1m 2s	remaining: 25.6s
# 709:	learn: 0.2746424	total: 1m 2s	remaining: 25.5s
# 710:	learn: 0.2746298	total: 1m 2s	remaining: 25.4s
# 711:	learn: 0.2746115	total: 1m 2s	remaining: 25.3s
# 712:	learn: 0.2745904	total: 1m 2s	remaining: 25.2s
# 713:	learn: 0.2745725	total: 1m 2s	remaining: 25.2s
# 714:	learn: 0.2745568	total: 1m 2s	remaining: 25.1s
# 715:	learn: 0.2745394	total: 1m 3s	remaining: 25s
# 716:	learn: 0.2745178	total: 1m 3s	remaining: 24.9s
# 717:	learn: 0.2745000	total: 1m 3s	remaining: 24.8s
# 718:	learn: 0.2744783	total: 1m 3s	remaining: 24.8s
# 719:	learn: 0.2744609	total: 1m 3s	remaining: 24.7s
# 720:	learn: 0.2744403	total: 1m 3s	remaining: 24.6s
# 721:	learn: 0.2744245	total: 1m 3s	remaining: 24.6s
# 722:	learn: 0.2744035	total: 1m 3s	remaining: 24.5s
# 723:	learn: 0.2743936	total: 1m 4s	remaining: 24.4s
# 724:	learn: 0.2743729	total: 1m 4s	remaining: 24.4s
# 725:	learn: 0.2743533	total: 1m 4s	remaining: 24.3s
# 726:	learn: 0.2743377	total: 1m 4s	remaining: 24.2s
# 727:	learn: 0.2742976	total: 1m 4s	remaining: 24.1s
# 728:	learn: 0.2742865	total: 1m 4s	remaining: 24s
# 729:	learn: 0.2742694	total: 1m 4s	remaining: 24s
# 730:	learn: 0.2742523	total: 1m 4s	remaining: 23.9s
# 731:	learn: 0.2742477	total: 1m 5s	remaining: 23.8s
# 732:	learn: 0.2742274	total: 1m 5s	remaining: 23.7s
# 733:	learn: 0.2742110	total: 1m 5s	remaining: 23.6s
# 734:	learn: 0.2741909	total: 1m 5s	remaining: 23.6s
# 735:	learn: 0.2741742	total: 1m 5s	remaining: 23.5s
# 736:	learn: 0.2741651	total: 1m 5s	remaining: 23.4s
# 737:	learn: 0.2741414	total: 1m 5s	remaining: 23.3s
# 738:	learn: 0.2741237	total: 1m 5s	remaining: 23.2s
# 739:	learn: 0.2741061	total: 1m 5s	remaining: 23.1s
# 740:	learn: 0.2740901	total: 1m 5s	remaining: 23s
# 741:	learn: 0.2740649	total: 1m 5s	remaining: 22.9s
# 742:	learn: 0.2740384	total: 1m 6s	remaining: 22.8s
# 743:	learn: 0.2740007	total: 1m 6s	remaining: 22.8s
# 744:	learn: 0.2739821	total: 1m 6s	remaining: 22.7s
# 745:	learn: 0.2739640	total: 1m 6s	remaining: 22.6s
# 746:	learn: 0.2739468	total: 1m 6s	remaining: 22.5s
# 747:	learn: 0.2739243	total: 1m 6s	remaining: 22.4s
# 748:	learn: 0.2739046	total: 1m 6s	remaining: 22.3s
# 749:	learn: 0.2738878	total: 1m 6s	remaining: 22.2s
# 750:	learn: 0.2738676	total: 1m 6s	remaining: 22.1s
# 751:	learn: 0.2738493	total: 1m 6s	remaining: 22s
# 752:	learn: 0.2738312	total: 1m 6s	remaining: 21.9s
# 753:	learn: 0.2738177	total: 1m 6s	remaining: 21.9s
# 754:	learn: 0.2738054	total: 1m 7s	remaining: 21.8s
# 755:	learn: 0.2737928	total: 1m 7s	remaining: 21.7s
# 756:	learn: 0.2737825	total: 1m 7s	remaining: 21.6s
# 757:	learn: 0.2737664	total: 1m 7s	remaining: 21.5s
# 758:	learn: 0.2737535	total: 1m 7s	remaining: 21.4s
# 759:	learn: 0.2737431	total: 1m 7s	remaining: 21.3s
# 760:	learn: 0.2737258	total: 1m 7s	remaining: 21.2s
# 761:	learn: 0.2737119	total: 1m 7s	remaining: 21.1s
# 762:	learn: 0.2736977	total: 1m 7s	remaining: 21s
# 763:	learn: 0.2736786	total: 1m 7s	remaining: 21s
# 764:	learn: 0.2736660	total: 1m 7s	remaining: 20.9s
# 765:	learn: 0.2736540	total: 1m 7s	remaining: 20.8s
# 766:	learn: 0.2736437	total: 1m 8s	remaining: 20.7s
# 767:	learn: 0.2736258	total: 1m 8s	remaining: 20.6s
# 768:	learn: 0.2736052	total: 1m 8s	remaining: 20.5s
# 769:	learn: 0.2735903	total: 1m 8s	remaining: 20.4s
# 770:	learn: 0.2735743	total: 1m 8s	remaining: 20.4s
# 771:	learn: 0.2735501	total: 1m 8s	remaining: 20.3s
# 772:	learn: 0.2735412	total: 1m 9s	remaining: 20.4s
# 773:	learn: 0.2735244	total: 1m 9s	remaining: 20.4s
# 774:	learn: 0.2735092	total: 1m 10s	remaining: 20.4s
# 775:	learn: 0.2734977	total: 1m 10s	remaining: 20.4s
# 776:	learn: 0.2734750	total: 1m 11s	remaining: 20.4s
# 777:	learn: 0.2734618	total: 1m 11s	remaining: 20.4s
# 778:	learn: 0.2734425	total: 1m 11s	remaining: 20.4s
# 779:	learn: 0.2734313	total: 1m 12s	remaining: 20.4s
# 780:	learn: 0.2734174	total: 1m 13s	remaining: 20.5s
# 781:	learn: 0.2733969	total: 1m 13s	remaining: 20.5s
# 782:	learn: 0.2733825	total: 1m 14s	remaining: 20.5s
# 783:	learn: 0.2733793	total: 1m 14s	remaining: 20.5s
# 784:	learn: 0.2733678	total: 1m 14s	remaining: 20.5s
# 785:	learn: 0.2733588	total: 1m 15s	remaining: 20.5s
# 786:	learn: 0.2733466	total: 1m 15s	remaining: 20.6s
# 787:	learn: 0.2733262	total: 1m 16s	remaining: 20.6s
# 788:	learn: 0.2733121	total: 1m 17s	remaining: 20.7s
# 789:	learn: 0.2732956	total: 1m 17s	remaining: 20.7s
# 790:	learn: 0.2732805	total: 1m 18s	remaining: 20.7s
# 791:	learn: 0.2732657	total: 1m 18s	remaining: 20.7s
# 792:	learn: 0.2732471	total: 1m 19s	remaining: 20.8s
# 793:	learn: 0.2732371	total: 1m 19s	remaining: 20.7s
# 794:	learn: 0.2732188	total: 1m 20s	remaining: 20.6s
# 795:	learn: 0.2732026	total: 1m 20s	remaining: 20.6s
# 796:	learn: 0.2731882	total: 1m 20s	remaining: 20.6s
# 797:	learn: 0.2731779	total: 1m 21s	remaining: 20.7s
# 798:	learn: 0.2731643	total: 1m 22s	remaining: 20.6s
# 799:	learn: 0.2731405	total: 1m 22s	remaining: 20.6s
# 800:	learn: 0.2731278	total: 1m 22s	remaining: 20.6s
# 801:	learn: 0.2731147	total: 1m 23s	remaining: 20.6s
# 802:	learn: 0.2731036	total: 1m 23s	remaining: 20.6s
# 803:	learn: 0.2730940	total: 1m 24s	remaining: 20.6s
# 804:	learn: 0.2730759	total: 1m 24s	remaining: 20.5s
# 805:	learn: 0.2730617	total: 1m 25s	remaining: 20.5s
# 806:	learn: 0.2730471	total: 1m 25s	remaining: 20.5s
# 807:	learn: 0.2730212	total: 1m 26s	remaining: 20.5s
# 808:	learn: 0.2730041	total: 1m 26s	remaining: 20.5s
# 809:	learn: 0.2729846	total: 1m 27s	remaining: 20.4s
# 810:	learn: 0.2729527	total: 1m 27s	remaining: 20.5s
# 811:	learn: 0.2729389	total: 1m 28s	remaining: 20.4s
# 812:	learn: 0.2729230	total: 1m 28s	remaining: 20.4s
# 813:	learn: 0.2729046	total: 1m 29s	remaining: 20.4s
# 814:	learn: 0.2728907	total: 1m 29s	remaining: 20.3s
# 815:	learn: 0.2728766	total: 1m 30s	remaining: 20.3s
# 816:	learn: 0.2728638	total: 1m 30s	remaining: 20.3s
# 817:	learn: 0.2728482	total: 1m 31s	remaining: 20.3s
# 818:	learn: 0.2728275	total: 1m 31s	remaining: 20.3s
# 819:	learn: 0.2728093	total: 1m 32s	remaining: 20.3s
# 820:	learn: 0.2727937	total: 1m 32s	remaining: 20.3s
# 821:	learn: 0.2727622	total: 1m 33s	remaining: 20.3s
# 822:	learn: 0.2727488	total: 1m 33s	remaining: 20.2s
# 823:	learn: 0.2727292	total: 1m 34s	remaining: 20.1s
# 824:	learn: 0.2727176	total: 1m 34s	remaining: 20s
# 825:	learn: 0.2727166	total: 1m 34s	remaining: 19.9s
# 826:	learn: 0.2727016	total: 1m 34s	remaining: 19.8s
# 827:	learn: 0.2726927	total: 1m 34s	remaining: 19.6s
# 828:	learn: 0.2726789	total: 1m 34s	remaining: 19.5s
# 829:	learn: 0.2726539	total: 1m 34s	remaining: 19.5s
# 830:	learn: 0.2726355	total: 1m 35s	remaining: 19.4s
# 831:	learn: 0.2726224	total: 1m 35s	remaining: 19.3s
# 832:	learn: 0.2725804	total: 1m 35s	remaining: 19.2s
# 833:	learn: 0.2725655	total: 1m 35s	remaining: 19.1s
# 834:	learn: 0.2725474	total: 1m 36s	remaining: 19s
# 835:	learn: 0.2725326	total: 1m 36s	remaining: 18.9s
# 836:	learn: 0.2725084	total: 1m 36s	remaining: 18.8s
# 837:	learn: 0.2724994	total: 1m 36s	remaining: 18.7s
# 838:	learn: 0.2724864	total: 1m 36s	remaining: 18.6s
# 839:	learn: 0.2724690	total: 1m 37s	remaining: 18.5s
# 840:	learn: 0.2724533	total: 1m 37s	remaining: 18.4s
# 841:	learn: 0.2724373	total: 1m 37s	remaining: 18.3s
# 842:	learn: 0.2724296	total: 1m 37s	remaining: 18.2s
# 888:	learn: 0.2717441	total: 1m 40s	remaining: 12.6s
# 889:	learn: 0.2717305	total: 1m 40s	remaining: 12.5s
# 890:	learn: 0.2717206	total: 1m 40s	remaining: 12.3s
# 891:	learn: 0.2717048	total: 1m 40s	remaining: 12.2s
# 892:	learn: 0.2716939	total: 1m 41s	remaining: 12.1s
# 893:	learn: 0.2716698	total: 1m 41s	remaining: 12s
# 894:	learn: 0.2716531	total: 1m 41s	remaining: 11.9s
# 895:	learn: 0.2716402	total: 1m 41s	remaining: 11.7s
# 896:	learn: 0.2716298	total: 1m 41s	remaining: 11.6s
# 897:	learn: 0.2716175	total: 1m 41s	remaining: 11.5s
# 898:	learn: 0.2715973	total: 1m 41s	remaining: 11.4s
# 899:	learn: 0.2715809	total: 1m 41s	remaining: 11.3s
# 900:	learn: 0.2715707	total: 1m 41s	remaining: 11.2s
# 901:	learn: 0.2715596	total: 1m 41s	remaining: 11s
# 902:	learn: 0.2715404	total: 1m 41s	remaining: 10.9s
# 903:	learn: 0.2715150	total: 1m 41s	remaining: 10.8s
# 904:	learn: 0.2715084	total: 1m 41s	remaining: 10.7s
# 905:	learn: 0.2714977	total: 1m 41s	remaining: 10.6s
# 906:	learn: 0.2714929	total: 1m 41s	remaining: 10.4s
# 907:	learn: 0.2714685	total: 1m 41s	remaining: 10.3s
# 908:	learn: 0.2714596	total: 1m 42s	remaining: 10.2s
# 909:	learn: 0.2714359	total: 1m 42s	remaining: 10.1s
# 910:	learn: 0.2714245	total: 1m 42s	remaining: 9.98s
# 911:	learn: 0.2714095	total: 1m 42s	remaining: 9.87s
# 912:	learn: 0.2714022	total: 1m 42s	remaining: 9.75s
# 913:	learn: 0.2713849	total: 1m 42s	remaining: 9.63s
# 914:	learn: 0.2713716	total: 1m 42s	remaining: 9.52s
# 915:	learn: 0.2713561	total: 1m 42s	remaining: 9.4s
# 916:	learn: 0.2713339	total: 1m 42s	remaining: 9.29s
# 917:	learn: 0.2713160	total: 1m 42s	remaining: 9.17s
# 918:	learn: 0.2713081	total: 1m 42s	remaining: 9.06s
# 919:	learn: 0.2712950	total: 1m 42s	remaining: 8.94s
# 920:	learn: 0.2712757	total: 1m 42s	remaining: 8.83s
# 921:	learn: 0.2712590	total: 1m 43s	remaining: 8.71s
# 922:	learn: 0.2712422	total: 1m 43s	remaining: 8.6s
# 923:	learn: 0.2712264	total: 1m 43s	remaining: 8.48s
# 924:	learn: 0.2712140	total: 1m 43s	remaining: 8.37s
# 925:	learn: 0.2712023	total: 1m 43s	remaining: 8.26s
# 926:	learn: 0.2711879	total: 1m 43s	remaining: 8.14s
# 927:	learn: 0.2711726	total: 1m 43s	remaining: 8.03s
# 928:	learn: 0.2711573	total: 1m 43s	remaining: 7.91s
# 929:	learn: 0.2711390	total: 1m 43s	remaining: 7.8s
# 930:	learn: 0.2711212	total: 1m 43s	remaining: 7.68s
# 931:	learn: 0.2711002	total: 1m 43s	remaining: 7.57s
# 932:	learn: 0.2710771	total: 1m 43s	remaining: 7.46s
# 933:	learn: 0.2710645	total: 1m 43s	remaining: 7.34s
# 934:	learn: 0.2710573	total: 1m 43s	remaining: 7.23s
# 935:	learn: 0.2710359	total: 1m 44s	remaining: 7.12s
# 936:	learn: 0.2710201	total: 1m 44s	remaining: 7s
# 937:	learn: 0.2710018	total: 1m 44s	remaining: 6.89s
# 938:	learn: 0.2709871	total: 1m 44s	remaining: 6.77s
# 939:	learn: 0.2709758	total: 1m 44s	remaining: 6.66s
# 940:	learn: 0.2709577	total: 1m 44s	remaining: 6.55s
# 941:	learn: 0.2709407	total: 1m 44s	remaining: 6.43s
# 942:	learn: 0.2709137	total: 1m 44s	remaining: 6.32s
# 943:	learn: 0.2708987	total: 1m 44s	remaining: 6.21s
# 944:	learn: 0.2708829	total: 1m 44s	remaining: 6.1s
# 945:	learn: 0.2708695	total: 1m 44s	remaining: 5.99s
# 946:	learn: 0.2708521	total: 1m 44s	remaining: 5.88s
# 947:	learn: 0.2708362	total: 1m 45s	remaining: 5.76s
# 948:	learn: 0.2708285	total: 1m 45s	remaining: 5.65s
# 949:	learn: 0.2708130	total: 1m 45s	remaining: 5.54s
# 950:	learn: 0.2708001	total: 1m 45s	remaining: 5.43s
# 951:	learn: 0.2707855	total: 1m 45s	remaining: 5.32s
# 952:	learn: 0.2707636	total: 1m 45s	remaining: 5.21s
# 953:	learn: 0.2707525	total: 1m 45s	remaining: 5.11s
# 954:	learn: 0.2707331	total: 1m 45s	remaining: 4.99s
# 955:	learn: 0.2707136	total: 1m 46s	remaining: 4.88s
# 956:	learn: 0.2706993	total: 1m 46s	remaining: 4.77s
# 957:	learn: 0.2706786	total: 1m 46s	remaining: 4.66s
# 958:	learn: 0.2706620	total: 1m 46s	remaining: 4.55s
# 959:	learn: 0.2706457	total: 1m 46s	remaining: 4.44s
# 960:	learn: 0.2706237	total: 1m 46s	remaining: 4.33s
# 961:	learn: 0.2706104	total: 1m 46s	remaining: 4.22s
# 962:	learn: 0.2705882	total: 1m 46s	remaining: 4.11s
# 963:	learn: 0.2705744	total: 1m 46s	remaining: 3.99s
# 964:	learn: 0.2705575	total: 1m 47s	remaining: 3.88s
# 965:	learn: 0.2705404	total: 1m 47s	remaining: 3.77s
# 966:	learn: 0.2705242	total: 1m 47s	remaining: 3.66s
# 967:	learn: 0.2705118	total: 1m 47s	remaining: 3.55s
# 968:	learn: 0.2704964	total: 1m 47s	remaining: 3.44s
# 969:	learn: 0.2704791	total: 1m 47s	remaining: 3.33s
# 970:	learn: 0.2704630	total: 1m 47s	remaining: 3.21s
# 971:	learn: 0.2704478	total: 1m 47s	remaining: 3.1s
# 972:	learn: 0.2704343	total: 1m 47s	remaining: 2.99s
# 973:	learn: 0.2704136	total: 1m 47s	remaining: 2.88s
# 974:	learn: 0.2703921	total: 1m 48s	remaining: 2.77s
# 975:	learn: 0.2703803	total: 1m 48s	remaining: 2.66s
# 976:	learn: 0.2703615	total: 1m 48s	remaining: 2.55s
# 977:	learn: 0.2703462	total: 1m 48s	remaining: 2.44s
# 978:	learn: 0.2703284	total: 1m 48s	remaining: 2.33s
# 979:	learn: 0.2702942	total: 1m 48s	remaining: 2.22s
# 980:	learn: 0.2702831	total: 1m 48s	remaining: 2.1s
# 981:	learn: 0.2702735	total: 1m 48s	remaining: 1.99s
# 982:	learn: 0.2702531	total: 1m 48s	remaining: 1.88s
# 983:	learn: 0.2702347	total: 1m 49s	remaining: 1.77s
# 984:	learn: 0.2702182	total: 1m 49s	remaining: 1.66s
# 985:	learn: 0.2702041	total: 1m 49s	remaining: 1.55s
# 986:	learn: 0.2701882	total: 1m 49s	remaining: 1.44s
# 987:	learn: 0.2701764	total: 1m 49s	remaining: 1.33s
# 988:	learn: 0.2701549	total: 1m 49s	remaining: 1.22s
# 989:	learn: 0.2701354	total: 1m 49s	remaining: 1.11s
# 990:	learn: 0.2701163	total: 1m 49s	remaining: 996ms
# 991:	learn: 0.2700981	total: 1m 49s	remaining: 885ms
# 992:	learn: 0.2700883	total: 1m 49s	remaining: 774ms
# 993:	learn: 0.2700672	total: 1m 49s	remaining: 664ms
# 994:	learn: 0.2700521	total: 1m 50s	remaining: 553ms
# 995:	learn: 0.2700424	total: 1m 50s	remaining: 442ms
# 996:	learn: 0.2700288	total: 1m 50s	remaining: 332ms
# 997:	learn: 0.2700156	total: 1m 50s	remaining: 221ms
# 998:	learn: 0.2699998	total: 1m 50s	remaining: 111ms
# 999:	learn: 0.2699912	total: 1m 50s	remaining: 0us
# Fold Accuracy: 0.868407792048178
# 5it [07:56, 95.24s/it]
# CatBoostClassifier의 5-fold 평균 Accuracy는 0.8678006513857308

# %%
# CatBoost 모델의 예측 결과 저장
t = pd.Timestamp.now()
fname = f"cat_submission_{t.month:02}{t.day:02}{t.hour:02}{t.minute:02}.csv"
pd.DataFrame({'ID': ID_test, 'STATUS': cat_pred_binary}).to_csv(fname, index=False)
print(f"'{fname}' is ready to submit.")

# %% [markdown]
# # DNN + LGBM + CAT Ensemble

# %%
import os
import pandas as pd

# 아래 폴더가 있다는 가정 하에 수행
# 해당 폴더에 lgbm, cat, DNN submission 파일 넣어야 함
folder = 'submissions' # 예측 결과 파일들이 저장된 폴더 경로
nf = 0

for f in os.listdir(folder):
    ext = os.path.splitext(f)[-1]
    if ext == '.csv': 
        s = pd.read_csv(os.path.join(folder, f))
    else: 
        continue
    if len(s.columns) != 2:
        continue
    if nf == 0: 
        slist = s
    else: 
        slist = pd.merge(slist, s, on="ID")
    nf += 1

p = 1    # 이 값에 따라 성능이 달라짐 (p=1: 산술평균, p>1: 멱평균)
if nf >= 2:
    pred = 0
    for j in range(nf): 
        pred = pred + slist.iloc[:, j + 1] ** p 
    pred = pred / nf    
    pred = pred ** (1/p)

    # threshold 값을 기준으로 0과 1로 나누기
    threshold = 0.495
    submission = pd.DataFrame({'ID': slist.ID, 'STATUS': (pred >= threshold).astype(int)})

    t = pd.Timestamp.now()
    fname = f"p{p}mean_submission_{t.month:02}{t.day:02}_{t.hour:02}{t.minute:02}.csv"
    submission.to_csv(fname, index=False)
